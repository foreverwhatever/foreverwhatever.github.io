# %% [markdown]
# Experiments with pie charts and CustomJsTransform

# %%
    # %load_ext literacy
    from bokeh import plotting, models; from coffeetools import coffee; import pandas as pd; plotting.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="148730cd-a82b-4ed8-8ab1-f09d18c34159">Loading BokehJS ...</span>
#     </div>

# %%
    source = pd.util.testing.makeDataFrame().sum().to_frame('x').abs().pipe(plotting.ColumnDataSource)
# Out:
#     source = pd.util.testing.makeDataFrame().sum().to_frame('x').abs().pipe(plotting.ColumnDataSource)

# %%
    def T(field, code="""return xs;""", **args):
        return dict(field=field, transform=models.CustomJSTransform(args=args, v_func=coffee.compile(code, bare=True)))
# Out:
#     def T(field, code="""return xs;""", **args):
#         return dict(field=field, transform=models.CustomJSTransform(args=args, v_func=coffee.compile(code, bare=True)))

# %%
    p = plotting.figure()
    p.add_glyph(
        source, 
        models.AnnularWedge(
            x=0, y=T('x', """return xs.map ()-> 0"""),
            end_angle=T('x', """return xs.map (v,i)-> i/xs.length*2*3.14159"""),
            start_angle=T('x', """return xs.map (v,i)-> (i+1)/xs.length*2*3.14159"""),
            outer_radius=T('x', """return xs.map (v)->1"""),
        )
    )
    plotting.show(p)
# Out:
#     p = plotting.figure()
#     p.add_glyph(
#         source,
#         models.AnnularWedge(
#             x=0, y=T('x', """return xs.map ()-> 0"""),
#             end_angle=T('x', """return xs.map (v,i)-> i/xs.length*2*3.14159"""),
#             start_angle=T('x', """return xs.map (v,i)-> (i+1)/xs.length*2*3.14159"""),
#             outer_radius=T('x', """return xs.map (v)->1"""),
#         )
#     )
#     plotting.show(p)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d3c550dc-d66a-44ba-94fc-570f00e2d5f1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d3c550dc-d66a-44ba-94fc-570f00e2d5f1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d3c550dc-d66a-44ba-94fc-570f00e2d5f1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd3c550dc-d66a-44ba-94fc-570f00e2d5f1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2c807084-3fda-48e8-87e8-b986a80b47e9":{"roots":{"references":[{"attributes":{"below":[{"id":"38be7fc0-e6b2-4918-96ce-ddcf57d0d059","type":"LinearAxis"}],"left":[{"id":"6f3023cf-6fa5-4366-bfd3-18110259431b","type":"LinearAxis"}],"renderers":[{"id":"38be7fc0-e6b2-4918-96ce-ddcf57d0d059","type":"LinearAxis"},{"id":"2d41c6a9-0cac-4922-8b73-e18679586120","type":"Grid"},{"id":"6f3023cf-6fa5-4366-bfd3-18110259431b","type":"LinearAxis"},{"id":"17ce6569-282a-471f-8269-4cabcfb3846c","type":"Grid"},{"id":"49e2f405-b994-43f5-ac2b-31d23b800758","type":"BoxAnnotation"},{"id":"41c2c067-f4f7-4ab9-815a-d9dcf0ac1800","type":"GlyphRenderer"}],"title":{"id":"2fe00db8-c566-4c81-a1d0-53a1dedcba6d","type":"Title"},"tool_events":{"id":"0fc02cea-d6da-4db9-b3c7-06413029c232","type":"ToolEvents"},"toolbar":{"id":"7cd4c0da-f233-4328-abb7-fa4d779a8202","type":"Toolbar"},"x_range":{"id":"e2960fc4-d017-438d-a70b-d4157ea256b0","type":"DataRange1d"},"y_range":{"id":"4352bf6f-9359-4796-a0b9-c59a1e14bcad","type":"DataRange1d"}},"id":"295d5e5f-eb09-4057-8311-986649c50746","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"295d5e5f-eb09-4057-8311-986649c50746","subtype":"Figure","type":"Plot"}},"id":"968af0d8-3c2f-4c7e-a88f-3deb2b168140","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"2fe00db8-c566-4c81-a1d0-53a1dedcba6d","type":"Title"},{"attributes":{"plot":{"id":"295d5e5f-eb09-4057-8311-986649c50746","subtype":"Figure","type":"Plot"}},"id":"b3e73fde-5686-4e9e-afdb-ae04a292648b","type":"PanTool"},{"attributes":{},"id":"0fc02cea-d6da-4db9-b3c7-06413029c232","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b3e73fde-5686-4e9e-afdb-ae04a292648b","type":"PanTool"},{"id":"17acdc9a-1996-4d7b-a3fc-982dc85bf77d","type":"WheelZoomTool"},{"id":"ad7f7797-d63b-4d55-bc30-303116684190","type":"BoxZoomTool"},{"id":"968af0d8-3c2f-4c7e-a88f-3deb2b168140","type":"SaveTool"},{"id":"15cc005b-14a7-4994-9551-89f6984f80d7","type":"ResetTool"},{"id":"3161afa0-e7c9-4bbf-8c7e-75901739d91b","type":"HelpTool"}]},"id":"7cd4c0da-f233-4328-abb7-fa4d779a8202","type":"Toolbar"},{"attributes":{"plot":{"id":"295d5e5f-eb09-4057-8311-986649c50746","subtype":"Figure","type":"Plot"}},"id":"15cc005b-14a7-4994-9551-89f6984f80d7","type":"ResetTool"},{"attributes":{"data_source":{"id":"22d3e580-7e4d-4748-8013-f9bcd750130f","type":"ColumnDataSource"},"glyph":{"id":"56976fd8-2c7b-4276-bea1-dd6b004e26de","type":"AnnularWedge"},"hover_glyph":null,"muted_glyph":null},"id":"41c2c067-f4f7-4ab9-815a-d9dcf0ac1800","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"e2960fc4-d017-438d-a70b-d4157ea256b0","type":"DataRange1d"},{"attributes":{"callback":null},"id":"4352bf6f-9359-4796-a0b9-c59a1e14bcad","type":"DataRange1d"},{"attributes":{},"id":"94c1268d-107c-4cc5-8d6d-b932bb4c774d","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"94c1268d-107c-4cc5-8d6d-b932bb4c774d","type":"BasicTickFormatter"},"plot":{"id":"295d5e5f-eb09-4057-8311-986649c50746","subtype":"Figure","type":"Plot"},"ticker":{"id":"3d48e7df-b3df-44c0-b8b5-eec960cc2c7e","type":"BasicTicker"}},"id":"6f3023cf-6fa5-4366-bfd3-18110259431b","type":"LinearAxis"},{"attributes":{"v_func":"// Generated by CoffeeScript 1.11.1\nreturn xs.map(function(v) {\n  return 1;\n});\n"},"id":"1e92e3a7-b265-47cf-98a7-39fdb32c0a15","type":"CustomJSTransform"},{"attributes":{},"id":"50797a2d-9792-45e5-9841-83ed4ac4af80","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"295d5e5f-eb09-4057-8311-986649c50746","subtype":"Figure","type":"Plot"},"ticker":{"id":"3d48e7df-b3df-44c0-b8b5-eec960cc2c7e","type":"BasicTicker"}},"id":"17ce6569-282a-471f-8269-4cabcfb3846c","type":"Grid"},{"attributes":{"v_func":"// Generated by CoffeeScript 1.11.1\nreturn xs.map(function(v, i) {\n  return i / xs.length * 2 * 3.14159;\n});\n"},"id":"b36dc6cc-7129-4963-8038-b304eb2f52a3","type":"CustomJSTransform"},{"attributes":{"v_func":"// ...

# %%
    p = plotting.figure()
    r = p.add_glyph(
        source, 
        models.AnnularWedge(
            x=0, y=T('x', """return xs.map ()-> 0"""),
            end_angle=T('x', """
            dx = Math.max 1, Math.abs(xx.start-xx.end)/2/1.5
            total = xs.reduce (p,n)->p+n
            current = ((Math.log Math.abs(xx.start-xx.end)/10)%1)*dx*2*3.14159            
            return xs.map (v, i)-> 
                if i > 0
                    current += xs[i-1]/total*2*3.14159
                current
            """, xx=p.x_range),
            start_angle=T('x', """
            dx = Math.max 1, Math.abs(xx.start-xx.end)/2/1.5
            total = xs.reduce (p,n)->p+n
            current = ((Math.log Math.abs(xx.start-xx.end)/10)%1)*dx*2*3.14159
            return xs.map (v, i)-> 
                current += v/total*2*3.14159 
                current
            """, xx=p.x_range),
            outer_radius=T('x', """
            dx = Math.max 1, Math.abs(xx.start-xx.end)/2/1.5
            return xs.map (v)-> dx
            """, xx=p.x_range),
            inner_radius=T('x', """
            dx = .1*Math.max 1, Math.abs(xx.start-xx.end)/2/1.5
            return xs.map (v)-> dx
            """, xx=p.x_range),
            fill_alpha=.6
        )
    )
    p.x_range.callback = p.y_range.callback = models.CustomJS(args=dict(source=source), code="""
    source.trigger('change');
    dx = Math.abs(cb_obj.start - cb_obj.end)/2
    cb_obj.start = dx
    cb_obj.end = -dx
    """)
    plotting.show(p)
# Out:
#     p = plotting.figure()
#     r = p.add_glyph(
#         source,
#         models.AnnularWedge(
#             x=0, y=T('x', """return xs.map ()-> 0"""),
#             end_angle=T('x', """
#             dx = Math.max 1, Math.abs(xx.start-xx.end)/2/1.5
#             total = xs.reduce (p,n)->p+n
#             current = ((Math.log Math.abs(xx.start-xx.end)/10)%1)*dx*2*3.14159
#             return xs.map (v, i)->
#                 if i > 0
#                     current += xs[i-1]/total*2*3.14159
#                 current
#             """, xx=p.x_range),
#             start_angle=T('x', """
#             dx = Math.max 1, Math.abs(xx.start-xx.end)/2/1.5
#             total = xs.reduce (p,n)->p+n
#             current = ((Math.log Math.abs(xx.start-xx.end)/10)%1)*dx*2*3.14159
#             return xs.map (v, i)->
#                 current += v/total*2*3.14159
#                 current
#             """, xx=p.x_range),
#             outer_radius=T('x', """
#             dx = Math.max 1, Math.abs(xx.start-xx.end)/2/1.5
#             return xs.map (v)-> dx
#             """, xx=p.x_range),
#             inner_radius=T('x', """
#             dx = .1*Math.max 1, Math.abs(xx.start-xx.end)/2/1.5
#             return xs.map (v)-> dx
#             """, xx=p.x_range),
#             fill_alpha=.6
#         )
#     )
#     p.x_range.callback = p.y_range.callback = models.CustomJS(args=dict(source=source), code="""
#     source.trigger('change');
#     dx = Math.abs(cb_obj.start - cb_obj.end)/2
#     cb_obj.start = dx
#     cb_obj.end = -dx
#     """)
#     plotting.show(p)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="57a5fff7-e6c6-4b74-920c-478cc3d58812"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("57a5fff7-e6c6-4b74-920c-478cc3d58812");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("57a5fff7-e6c6-4b74-920c-478cc3d58812");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '57a5fff7-e6c6-4b74-920c-478cc3d58812' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1b4fe433-ded3-4d28-9271-0deffe0af56e":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"146f4a58-4049-4131-aaae-a5bf7ed7ed06","type":"Title"},{"attributes":{"formatter":{"id":"0fc73e74-c433-40e1-b382-2f5e3b670e5b","type":"BasicTickFormatter"},"plot":{"id":"ec617a6f-ed78-474e-8c4a-7693bda4628c","subtype":"Figure","type":"Plot"},"ticker":{"id":"611178b4-e9af-4715-ba7f-91c3a6bd2453","type":"BasicTicker"}},"id":"7e1c5c2e-66f7-49a7-a763-5ed8e1467321","type":"LinearAxis"},{"attributes":{"callback":{"id":"60bb5b28-88e1-43d4-b312-49e37f96ef3d","type":"CustomJS"}},"id":"fe2504d6-95f4-4813-a564-b4b5f1c2d2c3","type":"DataRange1d"},{"attributes":{"args":{"xx":{"id":"3bfbb161-d7a1-4477-83fb-f09a7edbf441","type":"DataRange1d"}},"v_func":"// Generated by CoffeeScript 1.11.1\nvar current, dx, total;\n\ndx = Math.max(1, Math.abs(xx.start - xx.end) / 2 / 1.5);\n\ntotal = xs.reduce(function(p, n) {\n  return p + n;\n});\n\ncurrent = ((Math.log(Math.abs(xx.start - xx.end) / 10)) % 1) * dx * 2 * 3.14159;\n\nreturn xs.map(function(v, i) {\n  current += v / total * 2 * 3.14159;\n  return current;\n});\n"},"id":"6a135b35-713e-4ab4-ae65-e48af3f0d7f8","type":"CustomJSTransform"},{"attributes":{"plot":{"id":"ec617a6f-ed78-474e-8c4a-7693bda4628c","subtype":"Figure","type":"Plot"}},"id":"48d5538f-21b1-4a22-bbdf-ad1300d63727","type":"HelpTool"},{"attributes":{},"id":"5e10bfe2-7b84-4616-be5d-6171f0e361c7","type":"ToolEvents"},{"attributes":{"data_source":{"id":"22d3e580-7e4d-4748-8013-f9bcd750130f","type":"ColumnDataSource"},"glyph":{"id":"6c7304d5-37fc-4de9-ab08-b43d3065d95e","type":"AnnularWedge"},"hover_glyph":null,"muted_glyph":null},"id":"8d0b6a43-fcf8-4fae-8600-a611ce0afcab","type":"GlyphRenderer"},{"attributes":{},"id":"519f2eec-4412-4f7f-ae93-fe4102a59e71","type":"BasicTickFormatter"},{"attributes":{},"id":"b889d03b-716c-44bd-bbb8-025ef8417676","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"ec617a6f-ed78-474e-8c4a-7693bda4628c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b889d03b-716c-44bd-bbb8-025ef8417676","type":"BasicTicker"}},"id":"6cdc152c-e3ca-4885-861c-517354a3b19f","type":"Grid"},{"attributes":{},"id":"611178b4-e9af-4715-ba7f-91c3a6bd2453","type":"BasicTicker"},{"attributes":{},"id":"0fc73e74-c433-40e1-b382-2f5e3b670e5b","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"86c8aa6b-9308-4492-8fe6-ea91a3264f9e","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ec617a6f-ed78-474e-8c4a-7693bda4628c","subtype":"Figure","type":"Plot"}},"id":"c8026b1d-03b6-4a8e-b768-64b96dc7eba2","type":"PanTool"},{"attributes":{"overlay":{"id":"86c8aa6b-9308-4492-8fe6-ea91a3264f9e","type":"BoxAnnotation"},"plot":{"id":"ec617a6f-ed78-474e-8c4a-7693bda4628c","subtype":"Figure","type":"Plot"}},"id":"a7c60dd8-d163-4b44-a265-20ff96916153","type":"BoxZoomTool"},{"attributes":{"args":{"xx":{"id":"3bfbb161-d7a1-4477-83fb-f09a7edbf441","type":"DataRange1d"}},"v_func":"// Generated by CoffeeScript 1.11.1\nvar dx;\n\ndx = .1 * Math.max(1, Math.abs(xx.start - xx.end) / 2 / 1.5);\n\nreturn xs.map(function(v) {\n  return dx;\n});\n"},"id":"111d119c-5ad0-49e7-9e5e-ab86432ff60b","type":"CustomJSTransform"},{"attributes":{"plot":{"id":"ec617a6f-ed78-474e-8c4a-7693bda4628c","subtype":"Figure","type":"Plot"}},"id":"3d1aae09-60db-4f73-ad35-d3e7755ed9b3","type":"SaveTool"},{"attributes":{"below":[{"id":"7e1c5c2e-66f7-49a7-a763-5ed8e1467321","type":"LinearAxis"}],"left":[{"id":"017940f1-a8b2-430c-9a80-2a07c6c09d99","type":"LinearAxis"}],"renderers":[{"id":"7e1c5c2e-66f7-49a7-a763-5ed8e1467321","type":"LinearAxis"},{"id":"f0b1d5f6-9ed2-43f4-8bcb-af59b0de1f2c","type":"Grid"},{"id":"017940f1-a8b2-430c-9a80-2a07c6c09d9 ...
